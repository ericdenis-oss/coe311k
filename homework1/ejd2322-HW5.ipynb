# %%
import numpy as np
import matplotlib.pyplot as plt


def custom_least_squares(X, Y):
    n = len(X)

    sum_x = np.sum(X)
    sum_y = np.sum(Y)
    sum_x2 = np.sum(X**2)
    sum_xy = np.sum(X*Y)

    m = (n*sum_xy - sum_x*sum_y)/(n*sum_x2 - sum_x**2)
    b = (sum_y - m*sum_x)/n

    return m, b


def numpy_least_squares(X, Y):
    n = len(X)

    A = np.vstack([X, np.ones(n)]).T
    m, b = np.linalg.lstsq(A, Y, rcond=None)[0]

    return m, b


def residual_analysis(X, Y, m, b):

    Y_pred = m*X + b
    residuals = Y - Y_pred

    max_index = np.argmax(residuals)
    min_index = np.argmin(residuals)

    return residuals, max_index, min_index, Y_pred


#Usage

# Create X values
X = np.arange(0, 1.01, 0.01)
X = np.sort(X)

n = len(X)

# Random linear function
m_true = np.random.rand()*10
b_true = np.random.rand()*5

# Random error between -1 and 1
error = np.random.uniform(-1,1,n)

# Generate Y
Y = m_true*X + b_true + error


print("ORIGINAL EQUATION")
print(f"y = {m_true:.4f}x + {b_true:.4f}\n")


# Custom Least Squares
m_custom, b_custom = custom_least_squares(X, Y)

print("CUSTOM LEAST SQUARES")
print(f"Slope = {m_custom:.4f}")
print(f"Intercept = {b_custom:.4f}\n")


# Numpy Least Squares
m_np, b_np = numpy_least_squares(X, Y)

print("NUMPY LEAST SQUARES")
print(f"Slope = {m_np:.4f}")
print(f"Intercept = {b_np:.4f}\n")


# Residual Analysis
residuals, max_index, min_index, Y_pred = residual_analysis(X, Y, m_custom, b_custom)

print("RESIDUALS (First 10)")
for i in range(10):
    print(f"X={X[i]:.2f}, Residual={residuals[i]:.4f}")

print("\nLargest Residual:")
print(f"{residuals[max_index]:.4f} at X={X[max_index]:.2f}")

print("Smallest Residual:")
print(f"{residuals[min_index]:.4f} at X={X[min_index]:.2f}")


# Plot Results
plt.figure()

plt.scatter(X, Y, label="Data Points")

plt.plot(X, Y_pred,
         linewidth=3,
         label=f"Custom Fit: y={m_custom:.2f}x + {b_custom:.2f}")

plt.plot(X, m_np*X + b_np,
         linestyle="--",
         label=f"Numpy Fit: y={m_np:.2f}x + {b_np:.2f}")

plt.scatter(X[max_index], Y[max_index], s=100, label="Max Residual")
plt.scatter(X[min_index], Y[min_index], s=100, label="Min Residual")

plt.xlabel("X")
plt.ylabel("Y")
plt.title("Least Squares Comparison")

plt.legend()
plt.grid(True)

plt.show()
# Out:
# ORIGINAL EQUATION
# y = 4.7696x + 4.4431
#
# CUSTOM LEAST SQUARES
# Slope = 4.9694
# Intercept = 4.3470
#
# NUMPY LEAST SQUARES
# Slope = 4.9694
# Intercept = 4.3470
#
# RESIDUALS (First 10)
# X=0.00, Residual=0.3290
# X=0.01, Residual=0.6517
# X=0.02, Residual=0.2464
# X=0.03, Residual=0.6723
# X=0.04, Residual=-0.8398
# X=0.05, Residual=0.3892
# X=0.06, Residual=-0.0546
# X=0.07, Residual=-0.0370
# X=0.08, Residual=-0.6231
# X=0.09, Residual=-0.6854
#
# Largest Residual:
# 1.0065 at X=0.20
# Smallest Residual:
# -0.9042 at X=0.58
