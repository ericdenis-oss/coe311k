# %%
import numpy as np
import matplotlib.pyplot as plt

# --- PART 1 ---
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])

A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print(f"Slope: {m}, Intercept: {c}")

x = np.linspace(0, max(X), 100)
lstsq = m*x+c
plt.title("Least Square Regression Between the given Data Points")
plt.scatter(X, Y)
plt.plot(x, lstsq)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# --- PART 2 ---
Xrand = np.random.rand(5)
Yrand = np.random.rand(5)
idx = np.argsort(Xrand)
Xrand = Xrand[idx]
Yrand = Yrand[idx]
print("Randomized X Vector:", Xrand)
print("Randomized Y Vector:", Yrand)

B = np.vstack([Xrand, np.ones(len(Xrand))]).T
n, d = np.linalg.lstsq(B, Yrand, rcond=None)[0]
print("Slope:", n, "Intercept:", d)

x = np.linspace(Xrand.min(), Xrand.max(), 100)
y = n*x+d
plt.title("Least Square Regression Model of Randomized Vectors")
plt.xlabel("x")
plt.ylabel("y")
plt.scatter(Xrand, Yrand)
plt.plot(x, y)
plt.show()

# --- PART 3 ---
X1 = np.arange(0, 1.01, .01)
m = np.random.rand()
b = np.random.rand()
Y = m*X1+b+np.random.rand(X1.size)
print("Random Slope: ", m, "Random Intercept: ", b)

B = np.vstack([X1, np.ones(len(X1))]).T
n, d = np.linalg.lstsq(B, Y, rcond=None)[0]
print("Calculated Slope:", n, "Calculated Intercept:", d)

residuals = Y-(n*X1+d)
max_residual = np.argmax(residuals)
min_residual = np.argmin(residuals)
print("Max Residual: ", residuals[max_residual], "at point X= ", X1[max_residual])
print("Min Residual: ", residuals[min_residual], "at point X= ", X1[min_residual], "\n")

print("Every Residual:")
for i in range(len(residuals)):
    print(residuals[i])

plt.title("Least Square Regression Model of Own Linear Equation")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(X1, n*X1+d)
plt.scatter(X1, Y)
plt.show()
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001
# Randomized X Vector: [0.33318098 0.48771122 0.53909274 0.79324574 0.96978671]
# Randomized Y Vector: [0.9570356  0.19332174 0.45134891 0.58262532 0.09960349]
# Slope: -0.8172802723073699 Intercept: 0.9672631117404477
# Random Slope:  0.7615354028748536 Random Intercept:  0.4194087549971587
# Calculated Slope: 0.8988255398333955 Calculated Intercept: 0.8980152812722298
# Max Residual:  0.4774576656647802 at point X=  0.12
# Min Residual:  -0.5384139324148238 at point X=  0.58
#
# Every Residual:
# -0.298802510137646
# 0.006077649104523797
# -0.34322953093420894
# 0.23804983985783046
# 0.4309658018544156
# 0.14257225838725285
# 0.2955924900475332
# -0.4258252088530008
# 0.1113418349119567
# -0.09743295690091991
# -0.35292508617417695
# -0.4611143357539448
# 0.4774576656647802
# 0.06287753857712297
# -0.2143440258494107
# -0.46960146822358084
# 0.1845310534062088
# 0.3071233158492057
# 0.36475896758615867
# 0.3651514561273812
# 0.33072086156958447
# 0.11161517927600073
# 0.4509820783306884
# 0.05421965148378094
# 0.02968537550128514
# -0.1914607943618487
# 0.4580757815116039
# -0.31747057372076015
# -0.11336153193006537
# 0.20976224755489858
# 0.014800013808981882
# -0.35061908298962496
# 0.3729447389441023
# 0.15527716071676623
# 0.2995920525991085
# 0.018656645812725525
# 0.09177049722833219
# 0.22276191516879984
# 0.26733263789105033
# 0.4391920677071215
# 0.026557951483332287
# -0.23873996648215834
# -0.0689223484724899
# -0.212392857767012
# -0.3760720151678111
# 0.09711432416823085
# -0.44030715129671705
# -0.24370344476546824
# -0.2858097432593121
# -0.29358203674483185
# 0.1446071650278431
# 0.0018736879720449018
# -0.2579108419651772
# 0.3121182152415334
# 0.1824991414342303
# 0.1357437715878147
# -0.04579648849331486
# -0.5297844283170386
# -0.5384139324148238
# -0.5200735787373723
# -0.463216888217566
# -0.4511309500159839
# -0.11345545823838599
# 0.13909543198528285
# -0.3921691224450836
# 0.3821714720923304
# 0.33114408807177975
# 0.12751514505243833
# -0.40332127938652174
# -0.34920888838826447
# 0.2715280286409194
# -0.42299644280092097
# -0.051532030499381154
# 0.06145724065350433
# -0.12712925634700256
# -0.14778138654062278
# 0.3891303370064152
# -0.37865529991815206
# 0.29267741548169224
# -0.47854552419416274
# 0.2933780273647928
# 0.04573909313393765
# 0.3941883118672951
# 0.10886323853890989
# -0.5225311387660883
# 0.15219121093853927
# 0.2051695491598382
# -0.09233187213234673
# 0.06187555248120624
# -0.2076106627018781
# 0.17837817198189998
# 0.20009217479294872
# 0.18435351989059057
# -0.09838452704275924
# -0.45453398834603886
# 0.26004245596038356
# 0.36172375745257046
# 0.3210987325110186
# -0.06420223569403594
# 0.36744692051819405
# 0.36276998241722724
