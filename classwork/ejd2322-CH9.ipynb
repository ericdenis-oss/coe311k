# %%
import numpy as np
import matplotlib.pyplot as plt

# --- PART 1 ---
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])

A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print(f"Slope: {m}, Intercept: {c}")

x = np.linspace(0, max(X), 100)
lstsq = m*x+c
plt.figure(figsize=(10,6))
plt.title("Least Square Regression Between the given Data Points")
plt.scatter(X, Y)
plt.plot(x, lstsq)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# --- PART 2 ---
Xrand = np.random.rand(5)
Yrand = np.random.rand(5)
idx = np.argsort(Xrand)
Xrand = Xrand[idx]
Yrand = Yrand[idx]
print("Randomized X Vector:", Xrand)
print("Randomized Y Vector:", Yrand)

B = np.vstack([Xrand, np.ones(len(Xrand))]).T
n, d = np.linalg.lstsq(B, Yrand, rcond=None)[0]
print("Slope:", n, "Intercept:", d)

x = np.linspace(Xrand.min(), Xrand.max(), 100)
y = n*x+d
plt.figure(figsize=(10,6))
plt.title("Least Square Regression Model of Randomized Vectors")
plt.xlabel("x")
plt.ylabel("y")
plt.scatter(Xrand, Yrand)
plt.plot(x, y)
plt.show()

# --- PART 3 ---
X1 = np.arange(0, 1.01, .01)
m = np.random.rand()
b = np.random.rand()
Y = m*X1+b+np.random.rand(X1.size)
print("Random Slope: ", m, "Random Intercept: ", b)

B = np.vstack([X1, np.ones(len(X1))]).T
n, d = np.linalg.lstsq(B, Y, rcond=None)[0]
print("Calculated Slope:", n, "Calculated Intercept:", d)

residuals = Y-(n*X1+d)
max_residual = np.argmax(residuals)
min_residual = np.argmin(residuals)
print("Max Residual: ", residuals[max_residual], "at point X= ", X1[max_residual])
print("Min Residual: ", residuals[min_residual], "at point X= ", X1[min_residual], "\n")

print("Every Residual:")
for i in range(len(residuals)):
    print(residuals[i])

plt.figure(figsize=(10,6))
plt.title("Least Square Regression Model of Own Linear Equation")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(X1, n*X1+d)
plt.scatter(X1, Y)
plt.show()
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001
# Randomized X Vector: [0.34196332 0.53325539 0.79123269 0.8087883  0.89905356]
# Randomized Y Vector: [0.01742102 0.37147831 0.98521355 0.31247386 0.88684273]
# Slope: 1.3965506056475558 Intercept: -0.4277883641694451
# Random Slope:  0.8714701472454193 Random Intercept:  0.9742330505351805
# Calculated Slope: 0.7719541835402257 Calculated Intercept: 1.5237281252028603
# Max Residual:  0.4963247741284662 at point X=  0.79
# Min Residual:  -0.5341370238317271 at point X=  0.15
#
# Every Residual:
# 0.3755033363729243
# -0.1700080259512038
# -0.19426136241823877
# 0.4234445837504206
# -0.10584959155303997
# 0.39937694843607585
# -0.31878656873478994
# -0.2966273696204087
# -0.0680889982073305
# 0.3793051960500722
# 0.4080414070039522
# 0.19182269426151244
# -0.44262966364522716
# 0.3405620133260894
# 0.0237756287371238
# -0.5341370238317271
# 0.4369173434363056
# 0.42958925077645427
# 0.43906073202624807
# -0.46331012728997023
# 0.43570506155735234
# -0.45686836523964924
# -0.49212184209180965
# -0.4727216770108513
# 0.18939935870778735
# -0.20185337450601182
# 0.23832230120481124
# 0.015073568377423685
# -0.3192846393093951
# 0.34882727313062567
# 0.2946865513783037
# 0.03730134616140779
# 0.23453534235180795
# -0.3924952992593702
# 0.29828865694054874
# -0.43469073745891107
# -0.18012738760499758
# -0.2312596300374501
# 0.0578883896003386
# -0.44802203205478497
# -0.08391649060975626
# -0.44422872926887713
# 0.07528734822059957
# -0.10500921530127072
# -0.0775268358476271
# -0.007865149008296823
# 0.30298497517596035
# 0.3951932090738488
# 0.14891350249658752
# -0.01392806211933717
# -0.11100441359532631
# 0.311741240242966
# -0.33434030624097044
# -0.45925262084849083
# 0.09294878754581104
# -0.15729959401205806
# -0.3643386291333215
# 0.2359428922501019
# 0.3818995943085701
# 0.0452903034044112
# -0.3513899677276191
# 0.38697156215749207
# -0.11265509899591564
# 0.27147586719872985
# 0.4052854841171438
# -0.4556925495110493
# -0.1052924424977304
# -0.26802909414975984
# -0.3785927429084217
# 0.2938475097664406
# -0.016993207998949433
# -0.42067463727813936
# 0.03623579419791367
# -0.20605979914514672
# -0.22746725967176218
# 0.37765793741885734
# -0.1543041006745267
# 0.44292096551847315
# -0.13344845569970643
# 0.4963247741284662
# -0.03221295265723656
# 0.2404804769863862
# 0.2318508959988077
# 0.46216139932827094
# -0.441560238892432
# -0.3988126835639263
# -0.37540662664726243
# -0.2953670872428291
# 0.4135616011113745
# 0.39754938957160135
# 0.4115995949017699
# 0.4905165868201484
# 0.04168420218784563
# -0.11691715032721595
# -0.18414743154427882
# 0.3026949839879016
# 0.0942169611630641
# -0.18882954051443335
# -0.38436582242065054
# -0.2767020288666404
# 0.12210985787905981
