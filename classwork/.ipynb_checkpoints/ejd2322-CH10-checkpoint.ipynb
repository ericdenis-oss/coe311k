# %%
import numpy as np
import matplotlib.pyplot as plt

# --- PART 1 ---
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])

A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print(f"Slope: {m}, Intercept: {c}")

x = np.linspace(0, max(X), 100)
lstsq = m*x+c
plt.title("Least Square Regression Between the given Data Points")
plt.scatter(X, Y)
plt.plot(x, lstsq)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# --- PART 2 ---
Xrand = np.random.rand(5)
Yrand = np.random.rand(5)
idx = np.argsort(Xrand)
Xrand = Xrand[idx]
Yrand = Yrand[idx]
print("Randomized X Vector:", Xrand)
print("Randomized Y Vector:", Yrand)

B = np.vstack([Xrand, np.ones(len(Xrand))]).T
n, d = np.linalg.lstsq(B, Yrand, rcond=None)[0]
print("Slope:", n, "Intercept:", d)

x = np.linspace(Xrand.min(), Xrand.max(), 100)
y = n*x+d
plt.title("Least Square Regression Model of Randomized Vectors")
plt.xlabel("x")
plt.ylabel("y")
plt.scatter(Xrand, Yrand)
plt.plot(x, y)
plt.show()

# --- PART 3 ---
X1 = np.arange(0, 1.01, .01)
m = np.random.rand()
b = np.random.rand()
Y = m*X1+b+np.random.rand(X1.size)
print("Random Slope: ", m, "Random Intercept: ", b)

B = np.vstack([X1, np.ones(len(X1))]).T
n, d = np.linalg.lstsq(B, Y, rcond=None)[0]
print("Calculated Slope:", n, "Calculated Intercept:", d)

residuals = Y-(n*X1+d)
max_residual = np.argmax(residuals)
min_residual = np.argmin(residuals)
print("Max Residual: ", residuals[max_residual], "at point X= ", X1[max_residual])
print("Min Residual: ", residuals[min_residual], "at point X= ", X1[min_residual], "\n")

print("Every Residual:")
for i in range(len(residuals)):
    print(residuals[i])

plt.title("Least Square Regression Model of Own Linear Equation")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(X1, n*X1+d)
plt.scatter(X1, Y)
plt.show()
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001
# Randomized X Vector: [0.06431696 0.35739398 0.52349218 0.7293955  0.96573194]
# Randomized Y Vector: [0.13834631 0.21638356 0.78312156 0.31679284 0.29390419]
# Slope: 0.18421438718920058 Intercept: 0.25243231466791044
# Random Slope:  0.1471047538475534 Random Intercept:  0.4327950781452822
# Calculated Slope: 0.17342885761820956 Calculated Intercept: 0.9087688137154067
# Max Residual:  0.5206289788619889 at point X=  0.09
# Min Residual:  -0.4852277667305088 at point X=  0.58
#
# Every Residual:
# -0.33373601719377466
# -0.07958803205528397
# -0.17849573676265051
# 0.08927965984990138
# 0.33205286870005457
# -0.10514842321517959
# -0.02247199423039592
# -0.17882906792346787
# 0.17381025825124086
# 0.5206289788619889
# 0.004980687659759009
# -0.10359135115920726
# 0.305168700924879
# -0.28690206772174687
# -0.4605492593324932
# -0.21824405147433457
# 0.4965906988261626
# -0.35323060884362567
# 0.21597790188751143
# 0.027005546738121167
# 0.02503923550281295
# -0.42982634976519507
# -0.15123862802334187
# 0.057046262302322015
# -0.46302903904716125
# 0.5014332875296835
# 0.4731391648288328
# 0.3226173491364178
# -0.14085040501864587
# -0.2696159062278619
# 0.37993451661450417
# -0.38321685603315614
# -0.482347598010313
# 0.34017868342761415
# -0.19577702463654567
# 0.052568718699873895
# -0.15129170456529728
# 0.16002950187642384
# 0.12122530936337861
# -0.25141121054677196
# -0.34550191774956274
# 0.11863279839173568
# 0.08683211640173927
# 0.20663187406154782
# 0.2358018947866699
# 0.04837169041062861
# 0.274031676943147
# -0.18818759003824648
# -0.12374493206940707
# 0.2705911557274886
# -0.17907352874893268
# 0.4418297917705747
# 0.08012355575308294
# -0.4071223478189282
# 0.4035238618319199
# 0.21669205300538352
# 0.4079219931717277
# -0.4486743155512658
# -0.4852277667305088
# -0.4530473337368228
# 0.19918244276368013
# 0.14801146353931127
# -0.27628808068112953
# 0.08043560374947356
# 0.15458757726504802
# -0.18225571459121537
# 0.4137141520592571
# 0.015593735554040977
# 0.36390819610432823
# -0.21626229342280412
# 0.42779568441946436
# -0.4417527766604563
# -0.20921396127522152
# 0.10974499815078653
# 0.07849579147691621
# 0.35568048716936307
# 0.09328987766485963
# -0.023890482559916437
# 0.040262958977356655
# 0.396438654573644
# -0.1354941739653327
# 0.37324122828003503
# 0.0048244936770829305
# -0.30760098918121204
# -0.21070778009850377
# 0.49392025277440244
# -0.1408108851273311
# -0.4037019085040461
# -0.16195256521433032
# 0.24170525073477545
# -0.182415160329237
# -0.14624793396506597
# -0.19311786945557707
# -0.03207178074546557
# -0.3709379397264345
# -0.2550381036379279
# 0.4166562390171995
# -0.09010480049961156
# 0.419083905169785
# -0.2876399571178463
# -0.07878856536911871
