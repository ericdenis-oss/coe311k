# %% [markdown]
#  Hello Python! This is my very first notebook

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Any String!")
# Out:
# Any String!

# %%
print(5)
# Out:
# 5

# %%
print(5+10)
# Out:
# 15

# %%
print(True)
# Out:
# True

# %%
2+5
# Out:
# 7

# %%
print("hello world juan")
# Out:
# hello world juan

# %%
name = Eric
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9d4a4fb9e1e1> in <module>
# ----> 1 name = Eric
#
# NameError: name 'Eric' is not defined

# %%
num1 = 5
print(num1)
# Out:
# 5

# %%
a = "Hello"
b = True

# %%
type(num1)
# Out:
# int

# %%
numIn = input("Enter a number:")
# Out:
# Enter a number:6

# %%
print(type(numIn))
# Out:
# <class 'str'>

# %%
myfile = open("test.dat",'w')
myfile.write(numIn)
myfile.write("\n")
myfile.write("Hello World")
myfile.close()

# %%
a = 2
b = 3

print(a==b)
print(b!=a and a>b)
# Out:
# False
# False

# %%
mylist = ["Eric" , 10 , "yellow" , 42, "Alex" , "Black"]

# %%
import math 
import random

for i in range(0,50):
    value = int(random.uniform(-1,50))
    print(value)
# Out:
# 33
# 29
# 4
# 35
# 33
# 23
# 43
# 44
# 15
# 34
# 49
# 39
# 3
# 49
# 31
# 15
# 8
# 21
# 7
# 30
# 49
# 14
# 9
# 21
# 43
# 33
# 44
# 4
# 46
# 43
# 32
# 33
# 15
# 16
# 49
# 11
# 4
# 12
# 0
# 19
# 19
# 46
# 17
# 45
# 19
# 5
# 41
# 23
# 48
# 17

# %%
def montecarlo_pi(number_of_shots):
    for i in range(0,number_of_shots):
        x = random.uniform(-1,1)
        y = random.unifrom(-1,1)
        
        if (x*x + y*y < 1):
            number_ofshits = number_of_shots + 1
    
    return 4*counter/number_of_hits

# %%
montecarlo_pi(50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-47413f1e6965> in <module>
# ----> 1 montecarlo_pi(50)
#
# <ipython-input-35-dcbd96e4e313> in montecarlo_pi(number_of_shots)
#       2     for i in range(0,number_of_shots):
#       3         x = random.uniform(-1,1)
# ----> 4         y = random.unifrom(-1,1)
#       5
#       6         if (x*x + y*y < 1):
#
# AttributeError: module 'random' has no attribute 'unifrom'

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 2*np.pi, 50)

# %%
x
# Out:
# array([0.        , 0.12822827, 0.25645654, 0.38468481, 0.51291309,
#        0.64114136, 0.76936963, 0.8975979 , 1.02582617, 1.15405444,
#        1.28228272, 1.41051099, 1.53873926, 1.66696753, 1.7951958 ,
#        1.92342407, 2.05165235, 2.17988062, 2.30810889, 2.43633716,
#        2.56456543, 2.6927937 , 2.82102197, 2.94925025, 3.07747852,
#        3.20570679, 3.33393506, 3.46216333, 3.5903916 , 3.71861988,
#        3.84684815, 3.97507642, 4.10330469, 4.23153296, 4.35976123,
#        4.48798951, 4.61621778, 4.74444605, 4.87267432, 5.00090259,
#        5.12913086, 5.25735913, 5.38558741, 5.51381568, 5.64204395,
#        5.77027222, 5.89850049, 6.02672876, 6.15495704, 6.28318531])

# %%
plt.plot(x, np.sin(x))
plt.show()

# %%
plt.scatter(x, np.sin(x))

# %%
x = np.linspace(0, 2 * np.pi, 50)
plt.plot(x, np.sin(x), 'r-x', label='Sin(x)')
plt.plot(x, np.cos(x), 'g-^', label='Cos(x)')
plt.legend() # Display the legend.
plt.xlabel('Rads') # Add a label to the x-axis.
plt.ylabel('Amplitude') # Add a label to the y-axis.
plt.title('Sin and Cos Waves') # Add a graph title.
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
z1 = np.empty([2001,2001])
im = plt.imshow(z1, cmap='hot')
fig = plt.colorbar(im, orientation='horizontal')
plt.show(fig)

# %%
i = 0
j = 0
t = 1
z = np.empty([2001,2001])
for x in np.arange(-10,10,.01):
    print(x)
    i = i + 1
    j = 0
    for y in np.arange(-10,10,.01):
        j = j + 1
        z[i][j] = x*x + y*y
# Out:
# -10.0
# -9.99
# -9.98
# -9.97
# -9.96
# -9.950000000000001
# -9.940000000000001
# -9.930000000000001
# -9.920000000000002
# -9.910000000000002
# -9.900000000000002
# -9.890000000000002
# -9.880000000000003
# -9.870000000000003
# -9.860000000000003
# -9.850000000000003
# -9.840000000000003
# -9.830000000000004
# -9.820000000000004
# -9.810000000000004
# -9.800000000000004
# -9.790000000000004
# -9.780000000000005
# -9.770000000000005
# -9.760000000000005
# -9.750000000000005
# -9.740000000000006
# -9.730000000000006
# -9.720000000000006
# -9.710000000000006
# -9.700000000000006
# -9.690000000000007
# -9.680000000000007
# -9.670000000000007
# -9.660000000000007
# -9.650000000000007
# -9.640000000000008
# -9.630000000000008
# -9.620000000000008
# -9.610000000000008
# -9.600000000000009
# -9.590000000000009
# -9.580000000000009
# -9.57000000000001
# -9.56000000000001
# -9.55000000000001
# -9.54000000000001
# -9.53000000000001
# -9.52000000000001
# -9.51000000000001
# -9.50000000000001
# ...

# %%
def f1(x,y):
    return (x*x+y*y)
x = np.linspace(-10, 10, 1000)
y = np.linspace(-10, 10, 1000)
