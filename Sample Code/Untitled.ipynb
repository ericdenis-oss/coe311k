# %% [markdown]
# # Let's start with Hello World!

# %% [markdown]
# ## My sample notebook

# %% [markdown]
# ### Here's a sub-sub heading

# %%
i = 2147483647
i = i + 1
print(i)
# Out:
# 2147483648

# %% [markdown]
# ## Loss of Precision:
#
# IEEE 754 double precision floating point
